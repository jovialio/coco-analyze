# %%
## general imports
import json
import numpy as np
import sys

## COCO imports
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from pycocotools.cocoanalyze import COCOanalyze

## plotting imports
# %matplotlib inline
import matplotlib.pyplot as plt
import skimage.io as io

# %%
## set paths
#dataDir  = '.'
#dataType = 'val2014'
#annType  = 'person_keypoints'
#teamName = 'fakekeypoints100'

#annFile  = '%s/annotations/%s_%s.json'%(dataDir, annType, dataType)
#resFile  = '%s/detections/%s_%s_%s_results.json'%(dataDir, teamName, annType, dataType)
annFile  = '../../data/mscoco2017/annotations/person_keypoints_val2017.json'
resFile  = 'vis_val2017_158000_vgginit_None_None/json_detection.json'
print("{:10}[{}]".format('annFile:',annFile))
print("{:10}[{}]".format('resFile:',resFile))

# with open(annFile) as f:
#     gt_data = json.load(f)

# imgs_info = {i['id']:{'id':i['id'] ,
#                       'width':i['width'],
#                       'height':i['height']}
#                        for i in gt_data['images']}
# Out:
# annFile:  [../../data/mscoco2017/annotations/person_keypoints_val2017.json]
# resFile:  [vis_val2017_158000_vgginit_None_None/json_detection.json]

# %%
# with open(resFile) as f:
#     team_dts = json.load(f)

# team_dts = [d for d in team_dts if d['image_id'] in imgs_info]

# team_img_ids = set([d['image_id'] for d in team_dts])
# print("Loaded [{}] instances in [{}] images.".format(len(team_dts),len(imgs_info)))

## load ground truth annotations
coco_gt = COCO(annFile)
catIds = coco_gt.getCatIds(catNms=['person'])
keys = coco_gt.getImgIds(catIds=catIds)
print('Person images: ', len(keys))

## initialize COCO detections api
coco_dt   = coco_gt.loadRes(resFile)

## initialize COCO eval api
cocoEval = COCOeval(coco_gt, coco_dt, 'keypoints')
cocoEval.params.imgIds = keys
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# if teamName == 'fakekeypoints100':
#     imgIds  = sorted(coco_gt.getImgIds())[0:100]
#     coco_analyze.cocoEval.params.imgIds = imgIds
# Out:
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# Person images:  2693
# Loading and preparing results...
# DONE (t=0.44s)
# creating index...
# index created!
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=4.77s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.399
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.395
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.462

# %%
# use evaluate() method for standard coco evaluation
# input arguments:
#  - verbose   : verbose outputs    (default: False)
#  - makeplots : plots eval results (default: False)
#  - savedir   : path to savedir    (default: None)
#  - team_name : team name string   (default: None)

## initialize COCO analyze api
coco_analyze = COCOanalyze(coco_gt, coco_dt, 'keypoints')
coco_analyze.evaluate(verbose=True, makeplots=True)
# Out:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=4.59s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.12s).
# <mrr:2.0>Verbose Summary:
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.55      | area=   all | maxDets= 20 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.60      | area=   all | maxDets= 20 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.65      | area=   all | maxDets= 20 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.70      | area=   all | maxDets= 20 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.80      | area=   all | maxDets= 20 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.85      | area=   all | maxDets= 20 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.90      | area=   all | maxDets= 20 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.95      | area=   all | maxDets= 20 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.55      | area=   all | maxDets= 20 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.60      | area=   all | maxDets= 20 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.65      | area=   all | maxDets= 20 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.70      | area=   all | maxDets= 20 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] = 0.395
#  Average Recall     (AR) @[ IoU=0.80      | area=   all | maxDets= 20 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.85      | area=   all | maxDets= 20 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.90      | area=   all | maxDets= 20 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.95      | area=   all | maxDets= 20 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 0.399
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 0.462

# %%
## NOTE: the values below are all default

# set OKS threshold of the extended error analysis
coco_analyze.params.oksThrs       = [.5,.55,.6,.65,.7,.75,.8,.85,.9,.95]

# set OKS threshold required to match a detection to a ground truth
coco_analyze.params.oksLocThrs    = .1

# set KS threshold limits defining jitter errors
coco_analyze.params.jitterKsThrs = [.5,.85]

# set the localization errors to analyze and in what order
# note: different order will show different progressive improvement
# to study impact of single error type, study in isolation
coco_analyze.params.err_types = ['miss','swap','inversion','jitter']

# area ranges for evaluation
# 'all' range is union of medium and large
coco_analyze.params.areaRng       = [[32 ** 2, 1e5 ** 2]] #[96 ** 2, 1e5 ** 2],[32 ** 2, 96 ** 2]
coco_analyze.params.areaRngLbl    = ['all'] # 'large','medium' 

coco_analyze.params.maxDets = [20]

# %%
# use analyze() method for advanced error analysis 
# input arguments:
#  - check_kpts   : analyze keypoint localization errors for detections with a match (default: True)
#                 : default errors types are ['jitter','inversion','swap','miss']
#  - check_scores : analyze optimal score (maximizing oks over all matches) for every detection (default: True)
#  - check_bkgd   : analyze background false positives and false negatives (default: True)

coco_analyze.analyze(check_kpts=True, check_scores=True, check_bckgd=True)
# Out:
# Analyzing keypoint errors...
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.24s).
# DONE (t=8.45s).
# Analyzing detection scores...
# <mrr:2.0>Running per image *optimal score* evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=2.93s).
# DONE (t=4.97s).
# Analyzing background false positives and false negatives...
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.10s).
# DONE (t=4.00s).

# %%
# use summarize() method to get the results after progressive correction of errors
# input arguments:
#  - makeplots : plots eval results (default: False)
#  - savedir   : path to savedir    (default: None)
#  - team_name : team name string   (default: None)

coco_analyze.summarize(makeplots=True)
# Out:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.14s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# Correcting area range [all]:
# Correcting error type [miss]:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.12s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# Correcting error type [swap]:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.22s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# Correcting error type [inversion]:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.09s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# Correcting error type [jitter]:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.13s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# Correcting area range [all]:
# Correcting error type [score]:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=2.92s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# Correcting area range [all]:
# Correcting error type [bckgd. fp, fn]:
# <mrr:2.0>Running per image evaluation...
# <mrr:2.0>Evaluate annotation type *keypoints*
# <mrr:2.0>DONE (t=3.13s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.03s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).
# <mrr:2.0>Accumulating evaluation results...
# <mrr:2.0>DONE (t=0.02s).

# %%
## print the performance summary 
for stat in coco_analyze.stats: print(stat)
# Out:
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.05525818639798489, 'auc': 0.015408283675615588, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.13664987405541562, 'auc': 0.06618468859623901, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.22717254408060453, 'auc': 0.13939704609477524, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.31769521410579343, 'auc': 0.2343985611321088, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.39467884130982367, 'auc': 0.3186491848120492, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.4630037783375315, 'auc': 0.39479905762713713, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.5261335012594458, 'auc': 0.4632870441662646, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.5793450881612091, 'auc': 0.525451371870196, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.6243702770780857, 'auc': 0.5817880667599107, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'baseline', 'maxDets': 20, 'recall': 0.6640428211586902, 'auc': 0.6280927349816711, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.07714105793450882, 'auc': 0.0219574623667236, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.2906171284634761, 'auc': 0.16902240432685262, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.5248740554156172, 'auc': 0.41075706256182815, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.6789987405541562, 'auc': 0.6036221376990925, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.7498425692695214, 'auc': 0.6988787573523988, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.7814861460957179, 'auc': 0.7521837724456754, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.7920340050377834, 'auc': 0.7667911685585158, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.7964420654911839, 'auc': 0.7706739176300318, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.7992758186397985, 'auc': 0.7735728108665894, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'miss', 'maxDets': 20, 'recall': 0.8002204030226701, 'auc': 0.7850190626904214, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.08139168765743073, 'auc': 0.024499500196222365, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.3101385390428212, 'auc': 0.18833227816186762, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.5579345088161209, 'auc': 0.45019937866110854, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.7087531486146096, 'auc': 0.6443579242939632, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.7695214105793451, 'auc': 0.7269936345792023, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.7909319899244333, 'auc': 0.7659040213868108, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.7967569269521411, 'auc': 0.7688898701072263, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.7989609571788413, 'auc': 0.7722639564901593, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.8008501259445844, 'auc': 0.7835214097071513, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'swap', 'maxDets': 20, 'recall': 0.8013224181360201, 'auc': 0.7858478175288005, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.10154282115869018, 'auc': 0.03157460456126011, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.39058564231738035, 'auc': 0.25944986682311033, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.6569584382871536, 'auc': 0.5652612560154575, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.770308564231738, 'auc': 0.7295099170084526, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.7980163727959698, 'auc': 0.7651992973387874, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.8038413098236776, 'auc': 0.7798271340446699, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7801654683502418, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7833138375160441, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7852247167860614, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'inversion', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7872652960387466, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.30982367758186397, 'auc': 0.1952004118134084, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.7581863979848866, 'auc': 0.7008992313976877, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7603966362965534, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7716997669901395, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7768728194404875, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7799065872697379, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7801654683502418, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7833138375160441, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7852247167860614, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'jitter', 'maxDets': 20, 'recall': 0.8039987405541562, 'auc': 0.7872652960387466, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'score', 'maxDets': 20, 'recall': 0.2186712846347607, 'auc': 0.20520357582022722, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'score', 'maxDets': 20, 'recall': 0.6793136020151134, 'auc': 0.6570086265462698, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'score', 'maxDets': 20, 'recall': 0.7997481108312342, 'auc': 0.791644183790992, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'score', 'maxDets': 20, 'recall': 0.8046284634760705, 'auc': 0.8018424527261739, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'score', 'maxDets': 20, 'recall': 0.8051007556675063, 'auc': 0.8018481968427235, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'score', 'maxDets': 20, 'recall': 0.8065176322418136, 'auc': 0.8018771272203349, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'score', 'maxDets': 20, 'recall': 0.8069899244332494, 'auc': 0.8018867841618927, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'score', 'maxDets': 20, 'recall': 0.8074622166246851, 'auc': 0.8018907074459234, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'score', 'maxDets': 20, 'recall': 0.8077770780856424, 'auc': 0.8018964931771021, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'score', 'maxDets': 20, 'recall': 0.809036523929471, 'auc': 0.8019334483104134, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.2186712846347607, 'auc': 0.21782178217821782, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.6793136020151134, 'auc': 0.6732673267326733, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.7997481108312342, 'auc': 0.7920792079207921, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.8046284634760705, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.8051007556675063, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.8065176322418136, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.8069899244332494, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.8074622166246851, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.8077770780856424, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'bckgd_false_pos', 'maxDets': 20, 'recall': 0.809036523929471, 'auc': 0.801980198019802, 'areaRngLbl': 'all', 'oks': 0.5}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.95}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.9}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.85}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.8}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.75}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.7}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.65}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.6}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.55}
# {'err': 'false_neg', 'maxDets': 20, 'recall': 1.0, 'auc': 1.0, 'areaRngLbl': 'all', 'oks': 0.5}

# %%
## after analyze() has been called the following variables are available

# list of the corrected detections
corrected_dts = coco_analyze.corrected_dts['all']
print(corrected_dts[17])

i = 17
# info on keypoint detection localization error
print('good: %s'%corrected_dts[i]['good'])
print('miss: %s'%corrected_dts[i]['miss'])
print('swap: %s'%corrected_dts[i]['swap'])
print('inv.: %s'%corrected_dts[i]['inversion'])
print('jit.: %s\n'%corrected_dts[i]['jitter'])

# corrected keypoint locations
print('predicted keypoints:\n %s'%corrected_dts[i]['keypoints'])
print('corrected keypoints:\n %s\n'%corrected_dts[i]['opt_keypoints'])

# optimal detection score
print('original score: %s'%corrected_dts[i]['score'])
print('optimal score:  %s\n'%corrected_dts[i]['opt_score'])
# Out:
# {'category_id': 1, 'max_oks': 0.0, 'score': 0.8724287748336792, 'keypoints': [0, 0, 0, 0, 0, 0, 0, 0, 0, 549, 278, 2, 0, 0, 0, 550, 285, 2, 556, 285, 2, 551, 296, 2, 562, 294, 2, 548, 301, 2, 557, 299, 2, 551, 304, 2, 556, 303, 2, 551, 320, 2, 555, 320, 2, 561, 338, 2, 560, 337, 2], 'opt_score': 0.0, 'bbox': [0, 0, 562, 338], 'area': 189956, 'id': 18, 'image_id': 516143}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e1b7d06e8055> in <module>()
#       7 i = 17
#       8 # info on keypoint detection localization error
# ----> 9 print('good: %s'%corrected_dts[i]['good'])
#      10 print('miss: %s'%corrected_dts[i]['miss'])
#      11 print('swap: %s'%corrected_dts[i]['swap'])
#
# KeyError: 'good'

# %%
## after summarize() has been called the following variables are available

# list of the false positive detections and missed ground-truth annotations
false_pos_dts = coco_analyze.false_pos_dts
false_neg_gts = coco_analyze.false_neg_gts
for oks in coco_analyze.params.oksThrs:
    print("Oks:[%.2f] - Num.FP:[%d] - Num.FN:[%d]"%(oks,len(false_pos_dts['all',str(oks)]),len(false_neg_gts['all',str(oks)])))
